# %%
# PASO 1: Cargar datos preprocesados y preparar
# ---------------------------------------------

import sys, pathlib
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split

# Añadir src/ al path
PROJECT_ROOT = pathlib.Path().resolve().parent.parent  # notebooks/xgb → raíz
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import config as cfg

# Cargar dataset procesado
df = joblib.load(cfg.DATA / "processed" / "xgb_data.pkl")

print(f"✅ Datos cargados: {df.shape[0]:,} muestras | {len(df['ticker'].unique())} tickers")

# Separar train/test por fecha (80% - 20%)
split_date = df["date"].quantile(0.8)
df_train = df[df["date"] <= split_date].copy()
df_test  = df[df["date"] > split_date].copy()

print(f"📊 Train: {df_train.shape[0]:,} muestras | Test: {df_test.shape[0]:,}")
# Out:
# ✅ Datos cargados: 180,400 muestras | 40 tickers
# 📊 Train: 144,320 muestras | Test: 36,080

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from collections import defaultdict

modelos = {}
mae_scores = {}

features = ["ret_1d", "ret_5d", "vol_5d", "momentum"]

tickers = df["ticker"].unique()

for ticker in tickers:
    df_tr = df_train[df_train["ticker"] == ticker]
    df_te = df_test[df_test["ticker"] == ticker]
    
    X_train, y_train = df_tr[features], df_tr["target_5d"]
    X_test, y_test   = df_te[features], df_te["target_5d"]
    
    model = LGBMRegressor(n_estimators=200, random_state=42)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    
    modelos[ticker] = model
    mae_scores[ticker] = mae

    print(f"✅ {ticker:5} | MAE: {mae:.5f} | Train: {len(X_train):5} | Test: {len(X_test):5}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002758
# ✅ AAPL  | MAE: 0.02468 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002121
# ✅ ABT   | MAE: 0.02005 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.003304
# ✅ ADBE  | MAE: 0.03304 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002883
# ✅ AMZN  | MAE: 0.02809 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002378
# ✅ BAC   | MAE: 0.02688 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.013483
# ✅ BTC-USD | MAE: 0.04866 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002695
# ✅ COST  | MAE: 0.01927 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000181 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001915
# ✅ CRM   | MAE: 0.03093 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001945
# ✅ CSCO  | MAE: 0.02016 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001406
# ✅ CVX   | MAE: 0.02183 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000263 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001123
# ✅ DIS   | MAE: 0.02553 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.009872
# ✅ ETH-USD | MAE: 0.06620 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002488
# ✅ GOOGL | MAE: 0.02917 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000237 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002907
# ✅ HD    | MAE: 0.02149 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000237 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.000195
# ✅ IBM   | MAE: 0.02156 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.000533
# ✅ INTC  | MAE: 0.04561 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000163 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001864
# ✅ JNJ   | MAE: 0.01649 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002391
# ✅ JPM   | MAE: 0.02263 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000240 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001195
# ✅ KO    | MAE: 0.01433 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001819
# ✅ LIN   | MAE: 0.01635 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.003087
# ✅ MA    | MAE: 0.01742 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001924
# ✅ MCD   | MAE: 0.01632 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000176 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002071
# ✅ META  | MAE: 0.03447 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000234 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002071
# ✅ MRK   | MAE: 0.02089 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.003163
# ✅ MSFT  | MAE: 0.02199 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.004826
# ✅ NFLX  | MAE: 0.03429 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002246
# ✅ NKE   | MAE: 0.02962 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.005467
# ✅ NVDA  | MAE: 0.04760 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000203 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001829
# ✅ ORCL  | MAE: 0.03199 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001765
# ✅ PEP   | MAE: 0.01586 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001758
# ✅ PFE   | MAE: 0.02197 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001669
# ✅ PG    | MAE: 0.01515 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.000671
# ✅ T     | MAE: 0.02159 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.005621
# ✅ TSLA  | MAE: 0.06017 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.003291
# ✅ UNH   | MAE: 0.02813 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000236 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.002856
# ✅ V     | MAE: 0.01757 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.000642
# ✅ VZ    | MAE: 0.02132 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001587 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.000832
# ✅ WFC   | MAE: 0.02843 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001409
# ✅ WMT   | MAE: 0.01767 | Train:  3608 | Test:   902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 3608, number of used features: 4
# [LightGBM] [Info] Start training from score 0.001043
# ✅ XOM   | MAE: 0.02297 | Train:  3608 | Test:   902

# %%
# PASO 3: Guardar modelos y métricas
# ----------------------------------

# Guardar modelos
joblib.dump(modelos, cfg.DATA / "processed" / "xgb_model.pkl")
print("💾 Modelos guardados en xgb_model.pkl")

# Guardar errores MAE
joblib.dump(mae_scores, cfg.DATA / "processed" / "mae_xgb.pkl")
print("📈 MAE por ticker guardado en mae_xgb.pkl")
# Out:
# 💾 Modelos guardados en xgb_model.pkl
# 📈 MAE por ticker guardado en mae_xgb.pkl
